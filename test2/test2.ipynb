# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
x_data = np.array(
    [[100, 4],
     [ 50, 1],
     [100, 4],
     [100, 3],
     [ 50, 2],
     [ 80, 2],
     [ 75, 3],
     [ 65, 4],
     [ 90, 3],
     [ 90, 2]])

# %%
y_data = np.array([9.3, 4.8, 8.9, 6.5, 4.2, 6.2, 7.4, 6.0,  7.6, 6.1])

# %%
model = LinearRegression()
model.fit(x_data,y_data)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("coefficients: ", model.coef_)
w1 = model.coef_[0]
w2 = model.coef_[1]

print("intercept: ", model.intercept_)
b = model.intercept_

predict = model.predict(x_data)
print("predict: ", predict)
# Out:
# coefficients:  [0.04701969 0.68363883]
# intercept:  1.02423625254582
# predict:  [8.46076035 4.05885947 8.46076035 7.77712152 4.7424983  6.15308893
#  6.60162933 6.81507128 7.30692464 6.62328581]

# %%
ax = plt.figure().add_subplot(111,projection = '3d')
ax.scatter(x_data[:, 0], x_data[:, 1], y_data, c = 'b', marker = 'o', s = 50)
x0 = x_data[:, 0]
x1 = x_data[:, 1]
x0, x1 = np.meshgrid(x0,x1)
z = b + w1 * x0 + w2 * x1
ax.plot_surface(x0, x1, z, color = "r")
ax.set_xlabel("area")
ax.set_ylabel("num_rooms")
ax.set_zlabel("price")
plt.show()
